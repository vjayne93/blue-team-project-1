# %%
import pandas as pd

# Specify the file path
file_path = r'C:\Users\vjmar\Desktop\DataScience\blue-team-project-1\csv-data\anxiety-depression-data.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Filter rows where the "state" column is not equal to "United States"
by_state_df = df[(df['State'] != 'United States') & (df['Group'] == 'By State') & (df['Indicator'] == 'Symptoms of Anxiety Disorder or Depressive Disorder')]

# Display the filtered DataFrame
by_state_df.head()

state_mean_df = by_state_df.groupby('State')['Value'].mean()
print(state_mean_df)


state_mean_df.nlargest(3)

state_mean_df.nsmallest(3)

Basic Needs 
Food Scarcity
Housing Insecurity

Financial Factors 
Employment by Industry
Unemployment
Income per Capita

Education
Public School Funding
Student Loan Debt 
Educational Attainment 

Medical Factors 
Percent of Population Insured
Medical Professionals Per Capita
Medicaid & CHIP Enrollment 

# basic needs: food scarcity, housing insecurity for the 3 largest + 3 smallest states of depression & anxiety

# import pandas as pd

# # Specify the file path
# file_path = '/Users/victoriaro/Desktop/Data_Science_Bootcamp/blue-team-project-1/csv-data/food-scarcity-data.csv'

# # # Read the CSV file using the specified file path
# df = pd.read_csv(file_path)
# df
# # # list, group by, revelvant states (6) 
# # # Filter rows where the "state" column is not equal to "United States"
# # by_state_df = df[(df['State'] != 'United States') & (df['Group'] == 'By State')]

# # # Display the filtered DataFrame
# # by_state_df.head()

import pandas as pd
import os
import csv

csvpath = os.path.join("csv-data", "food-insecurity-data.csv")

df = pd.read_csv(csvpath)
df
